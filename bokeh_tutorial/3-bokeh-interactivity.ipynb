# %%
3-bokeh-interactivity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6453c3c9a1e1> in <module>()
# ----> 1 3-bokeh-interactivity
#
# NameError: name 'bokeh' is not defined

# %%
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.plotting import figure, output_notebook, show

output_notebook()

x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
        var data = source.data;
        var f = cb_obj.value
        var x = data['x']
        var y = data['y']
        for (var i = 0; i < x.length; i++) {
            y[i] = Math.pow(x[i], f)
        }
        source.change.emit();
    """)

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power", callback=callback)

layout = column(slider, plot)

show(layout)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="49dcd254-b422-4730-96ce-0597afeb8ab1">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="df2ad069-fe9c-46c6-a3a6-699955d0df4d"></div>
# </div>

# %%
import pandas as pd
import numpy as np
chess_data = pd.read_csv('../data/chess_data.csv')

print(np.mean(chess_data['age']))
print(np.mean(chess_data['rating']))

chess_plot = figure(plot_height=800, plot_width=1200)
chess_plot.circle(chess_data['age'],chess_data['rating'],size=chess_data['rating']/60,fill_color='orange',
                  fill_alpha=0.3*chess_data['age'],line_color='orange',
                  line_alpha=0.3*chess_data['age'])
#death_plot.line(death_data['rating'],death_data['Suicide'],line_color='purple',legend='Suicide')
chess_plot.xaxis.major_label_text_font_size = "32pt";
chess_plot.yaxis.major_label_text_font_size = "24pt";

show(chess_plot)
# Out:
# 24.266666666666666
# 1678.6333333333334
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b14e6b4e-df8b-4d5a-884b-6edfa0d80a2b"></div>
# </div>
